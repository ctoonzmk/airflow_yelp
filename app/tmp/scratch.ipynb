# %%
# !pip install pandas
# !pip install --upgrade pip
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('uszips.csv')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 9.9 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 9.7 MB/s eta 0:00:00:00:0100:01
# ...
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
df.head()
# Out:
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18027 -66.75266   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36075 -67.17541     Aguada       PR  Puerto Rico  True
# 2  603  18.45744 -67.12225  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16585 -66.93716    Maricao       PR  Puerto Rico  True
# 4  610  18.29110 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN     16773.0    100.5        72001    Adjuntas
# 1          NaN     37083.0    472.1        72003      Aguada
# 2          NaN     45652.0    513.2        72005   Aguadilla
# 3          NaN      6231.0     54.3        72093     Maricao
# 4          NaN     26502.0    275.7        72011      Añasco
#
#                                       county_weights  \
# 0                    {"72001": 98.73, "72141": 1.27}
# 1                                     {"72003": 100}
# ...

# %%
selected_columns=df.loc[:, ['zip', 'state_id']]
selected_columns.head()
len(selected_columns.index)
# Out:
# 33788

# %%
# Group the rows of the DataFrame by the 'state_id' column
groups = df.groupby('state_id')

# Convert each group to a dictionary where the keys are the 'state_id' values and the values are the rows from the DataFrame
dicts = {name: group.to_dict(orient='state_id') for name, group in groups}

print(dicts)
# Out:
# /tmp/ipykernel_8619/3740819725.py:5: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   dicts = {name: group.to_dict(orient='state_id') for name, group in groups}
# {'AK': {'zip': state_id
# AK    99501
# AK    99502
# AK    99503
# AK    99504
# AK    99505
#       ...
# AK    99923
# AK    99925
# AK    99926
# AK    99927
# AK    99929
# Name: zip, Length: 245, dtype: int64, 'state_name': state_id
# AK    Alaska
# AK    Alaska
# AK    Alaska
# AK    Alaska
# AK    Alaska
#        ...
# AK    Alaska
# AK    Alaska
# AK    Alaska
# AK    Alaska
# AK    Alaska
# Name: state_name, Length: 245, dtype: object, 'zcta': state_id
# AK    True
# AK    True
# AK    True
# AK    True
# AK    True
#       ...
# AK    True
# AK    True
# AK    True
# AK    True
# AK    True
# ...
